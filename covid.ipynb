# %% [markdown]
# <a href="https://colab.research.google.com/github/stevecodes23/CP/blob/main/covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
covid_data = pd.read_csv("/content/covid_19_india.csv")
#covid_data['Date'] =  pd.to_datetime(covid_data['Date'] ,format ='%d-%m-%Y')
covid_data.head()
# Out:
#    Sno        Date     Time  ... Cured Deaths Confirmed
# 0    1  2020-01-30  6:00 PM  ...     0      0         1
# 1    2  2020-01-31  6:00 PM  ...     0      0         1
# 2    3  2020-02-01  6:00 PM  ...     0      0         2
# 3    4  2020-02-02  6:00 PM  ...     0      0         3
# 4    5  2020-02-03  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
covid_data.info()
covid_data['Date'] = covid_data['Date'].astype('datetime64[ns]')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16850 entries, 0 to 16849
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       16850 non-null  int64
#  1   Date                      16850 non-null  object
#  2   Time                      16850 non-null  object
#  3   State/UnionTerritory      16850 non-null  object
#  4   ConfirmedIndianNational   16850 non-null  object
#  5   ConfirmedForeignNational  16850 non-null  object
#  6   Cured                     16850 non-null  int64
#  7   Deaths                    16850 non-null  int64
#  8   Confirmed                 16850 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
covid_data.describe()
# Out:
#                 Sno         Cured         Deaths     Confirmed
# count  16850.000000  1.685000e+04   16850.000000  1.685000e+04
# mean    8425.500000  2.360353e+05    3485.222552  2.583667e+05
# std     4864.320353  5.225438e+05    9330.541749  5.672808e+05
# min        1.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     4213.250000  2.658500e+03      22.000000  3.644750e+03
# 50%     8425.500000  2.889500e+04     453.000000  3.336150e+04
# 75%    12637.750000  2.537510e+05    3071.250000  2.666530e+05
# max    16850.000000  5.872268e+06  123531.000000  6.113335e+06

# %%
state_wise = covid_data.groupby('State/UnionTerritory')['Confirmed','Cured','Deaths'].sum().reset_index()
state_wise["Death_percentage"] = ((state_wise["Deaths"] / state_wise["Confirmed"]) * 100)
state_wise.style.background_gradient(cmap='magma')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <style  type="text/css" >
# #T_dacf533a_e6fd_11eb_b657_0242ac1c0002row0_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row0_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row0_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row2_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row5_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row5_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row5_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row6_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row6_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row6_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row6_col4,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row9_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row9_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row9_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row10_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row10_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row10_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row11_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row11_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row11_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row11_col4,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row21_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row21_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row21_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row22_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row22_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row22_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row26_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row27_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row27_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row27_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row28_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row33_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row33_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row33_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row38_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row38_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row38_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row38_col4{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row0_col4{
#             background-color:  #ae347b;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row1_col1{
#             background-color:  #7b2382;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row1_col2{
#             background-color:  #812581;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row1_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row14_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row14_col2{
#             background-color:  #1d1147;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row1_col4{
#             background-color:  #59157e;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row2_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row2_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row7_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row25_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row26_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row26_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row28_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row28_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row37_col3{
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row2_col4,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row4_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row15_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row23_col2{
#             background-color:  #1c1044;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row3_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row31_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row31_col2{
#             background-color:  #110c2f;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row3_col2{
#             background-color:  #120d31;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row3_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row13_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row13_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row16_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row16_col2{
#             background-color:  #02020d;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row3_col4,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row36_col4{
#             background-color:  #3d0f71;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row4_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row15_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row23_col1{
#             background-color:  #1a1042;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row4_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row35_col1{
#             background-color:  #050416;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row4_col4{
#             background-color:  #51127c;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row5_col4,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row39_col4{
#             background-color:  #aa337d;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row7_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row7_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row25_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row25_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row35_col3{
#             background-color:  #010106;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row7_col4,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row34_col4{
#             background-color:  #b2357b;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row8_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row8_col2,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row32_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row32_col2{
#             background-color:  #221150;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row8_col3{
#             background-color:  #100b2d;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row8_col4{
#             background-color:  #9c2e7f;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row9_col4,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row30_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row37_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row37_col2{
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row10_col4,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row36_col3{
#             background-color:  #02020b;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row12_col1{
#             background-color:  #54137d;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row12_col2{
#             background-color:  #5a167e;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row12_col3{
#             background-color:  #3f0f72;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row12_col4{
#             background-color:  #e24d66;
#             color:  #000000;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row13_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row16_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row30_col1,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row30_col2{
#             background-color:  #020109;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row13_col4{
#             background-color:  #c73d73;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row14_col3{
#             background-color:  #130d34;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row14_col4{
#             background-color:  #d6456c;
#             color:  #f1f1f1;
#         }#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row15_col3,#T_dacf533a_e6fd_11eb_b657_0242ac1c0002row32_col3{
#             background-color:  #090720;
#             color:  #f1f

# %%
px.bar(x=state_wise.nlargest(10,"Confirmed")["State/UnionTerritory"],
       y = state_wise.nlargest(10,"Confirmed")["Confirmed"],
       color_discrete_sequence=px.colors.diverging.Picnic,
       title="Top 10 states with highest number of Confirmed cases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b811f47e-b5f2-4a3c-976e-e43d1677f722" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b811f47e-b5f2-4a3c-976e-e43d1677f722")) {
#                     Plotly.newPlot(
#                         'b811f47e-b5f2-4a3c-976e-e43d1677f722',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(0,0,255)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Karnataka", "Kerala", "Tamil Nadu", "Andhra Pradesh", "Uttar Pradesh", "Delhi", "West Bengal", "Rajasthan", "Chhattisgarh"], "xaxis": "x", "y": [908892470, 387597335, 344319045, 342829697, 324146783, 252843682, 236972842, 209822848, 128998101, 128751782], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=state_wise.nlargest(10,"Deaths")["State/UnionTerritory"],
       y = state_wise.nlargest(10,"Deaths")["Deaths"],
       color_discrete_sequence=px.colors.diverging.curl,
       title="Top 10 states with highest number of Deaths")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c2ed0284-fe00-4aca-b1cc-0be0659fcd51" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c2ed0284-fe00-4aca-b1cc-0be0659fcd51")) {
#                     Plotly.newPlot(
#                         'c2ed0284-fe00-4aca-b1cc-0be0659fcd51',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(20, 29, 67)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Karnataka", "Tamil Nadu", "Delhi", "Uttar Pradesh", "West Bengal", "Andhra Pradesh", "Punjab", "Gujarat", "Chhattisgarh"], "xaxis": "x", "y": [19314532, 4819018, 4731627, 4066907, 3347656, 3214840, 2475816, 2216735, 1866811, 1591126], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=state_wise.nlargest(10,"Cured")["State/UnionTerritory"],
       y = state_wise.nlargest(10,"Cured")["Cured"],
       color_discrete_sequence=px.colors.sequential.Sunset,
       title="Top 10 states with highest number of Cured cases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8e553777-ef36-4911-8931-c896bd6fc47a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e553777-ef36-4911-8931-c896bd6fc47a")) {
#                     Plotly.newPlot(
#                         '8e553777-ef36-4911-8931-c896bd6fc47a',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "rgb(243, 231, 155)"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Maharashtra", "Karnataka", "Tamil Nadu", "Kerala", "Andhra Pradesh", "Uttar Pradesh", "Delhi", "West Bengal", "Odisha", "Rajasthan"], "xaxis": "x", "y": [813788907, 345648926, 317067499, 311127643, 303427899, 232529439, 224062704, 195296839, 117984789, 117312772], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
px.bar(x=state_wise.nlargest(10,"Death_percentage")["State/UnionTerritory"],
       y = state_wise.nlargest(10,"Death_percentage")["Death_percentage"],
       color_discrete_sequence=px.colors.qualitative.G10,
       title="Top 10 states with highest of Death percentage")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1682751f-4344-43e2-833e-682e7de46215" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1682751f-4344-43e2-833e-682e7de46215")) {
#                     Plotly.newPlot(
#                         '1682751f-4344-43e2-833e-682e7de46215',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "#3366CC"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Punjab", "Maharashtra", "Sikkim", "Uttarakhand", "Delhi", "Gujarat", "Himachal Pradesh", "Puducherry", "West Bengal", "Goa"], "xaxis": "x", "y": [2.80601089766184, 2.1250623849925834, 1.7935503876236818, 1.7691177403379106, 1.716191174345624, 1.6295826340309196, 1.6134329503567801, 1.574424063327307, 1.5321686988063379, 1.5186625353202514], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# # monthly analysis

# %%
month_wise = covid_data.groupby(pd.Grouper(key='Date',freq='M')).sum()

month_wise = month_wise.drop(['Sno'], axis = 1)
month_wise['Date'] = month_wise.index

first_column = month_wise.pop('Date')
month_wise.insert(0, 'Date', first_column)

index = [x for x in range(len(month_wise))]
month_wise['index'] = index
month_wise = month_wise.set_index('index')

second_column = month_wise.pop('Confirmed')
month_wise.insert(1, 'Confirmed', second_column)
month_wise["Death_percentage"] = ((month_wise["Deaths"] / month_wise["Confirmed"]) * 100)
month_wise.style.background_gradient(cmap='twilight_shifted')
# Out:
# <style  type="text/css" >
# #T_17e76f16_e701_11eb_b657_0242ac1c0002row0_col1,#T_17e76f16_e701_11eb_b657_0242ac1c0002row0_col2,#T_17e76f16_e701_11eb_b657_0242ac1c0002row0_col3,#T_17e76f16_e701_11eb_b657_0242ac1c0002row0_col4,#T_17e76f16_e701_11eb_b657_0242ac1c0002row1_col1,#T_17e76f16_e701_11eb_b657_0242ac1c0002row1_col2,#T_17e76f16_e701_11eb_b657_0242ac1c0002row1_col3,#T_17e76f16_e701_11eb_b657_0242ac1c0002row1_col4,#T_17e76f16_e701_11eb_b657_0242ac1c0002row2_col1,#T_17e76f16_e701_11eb_b657_0242ac1c0002row2_col2,#T_17e76f16_e701_11eb_b657_0242ac1c0002row2_col3,#T_17e76f16_e701_11eb_b657_0242ac1c0002row3_col1,#T_17e76f16_e701_11eb_b657_0242ac1c0002row3_col2,#T_17e76f16_e701_11eb_b657_0242ac1c0002row3_col3,#T_17e76f16_e701_11eb_b657_0242ac1c0002row4_col2{
#             background-color:  #301437;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row2_col4{
#             background-color:  #c68b6e;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row3_col4,#T_17e76f16_e701_11eb_b657_0242ac1c0002row17_col1,#T_17e76f16_e701_11eb_b657_0242ac1c0002row17_col2,#T_17e76f16_e701_11eb_b657_0242ac1c0002row17_col3{
#             background-color:  #2f1436;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row4_col1{
#             background-color:  #301338;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row4_col3{
#             background-color:  #32123a;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row4_col4{
#             background-color:  #381139;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row5_col1{
#             background-color:  #33113c;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row5_col2{
#             background-color:  #31123a;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row5_col3{
#             background-color:  #371144;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row5_col4{
#             background-color:  #3c113b;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row6_col1{
#             background-color:  #3a1149;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row6_col2{
#             background-color:  #361142;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row6_col3{
#             background-color:  #491564;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row6_col4{
#             background-color:  #a03d50;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row7_col1{
#             background-color:  #511a75;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row7_col2{
#             background-color:  #481563;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row7_col3,#T_17e76f16_e701_11eb_b657_0242ac1c0002row8_col2{
#             background-color:  #5c3499;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row7_col4{
#             background-color:  #ceab92;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row8_col1{
#             background-color:  #5e45a6;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row8_col3{
#             background-color:  #5f64b5;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row8_col4{
#             background-color:  #e0d6da;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row9_col1{
#             background-color:  #6379bb;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row9_col2{
#             background-color:  #606eb8;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row9_col3{
#             background-color:  #7196c1;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row9_col4{
#             background-color:  #ded9e1;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row10_col1{
#             background-color:  #6d90c0;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row10_col2{
#             background-color:  #6b8cbf;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row10_col3{
#             background-color:  #85a9c4;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row10_col4{
#             background-color:  #d6d7dd;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row11_col1{
#             background-color:  #84a8c4;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row11_col2,#T_17e76f16_e701_11eb_b657_0242ac1c0002row13_col1{
#             background-color:  #82a7c3;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row11_col3{
#             background-color:  #a6bfca;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row11_col4{
#             background-color:  #d3d6db;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row12_col1{
#             background-color:  #91b2c6;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row12_col2{
#             background-color:  #93b4c6;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row12_col3{
#             background-color:  #b8c9d0;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row12_col4{
#             background-color:  #d2d5db;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row13_col2{
#             background-color:  #86aac4;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row13_col3{
#             background-color:  #a0bcc9;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row13_col4{
#             background-color:  #ced3d9;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row14_col1{
#             background-color:  #a9c1cb;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row14_col2{
#             background-color:  #acc2cc;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row14_col3{
#             background-color:  #c7d0d5;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row14_col4{
#             background-color:  #c5cfd5;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row15_col1{
#             background-color:  #e2d9e2;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row15_col2{
#             background-color:  #d0d4d9;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row15_col3{
#             background-color:  #dcd9df;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row15_col4{
#             background-color:  #9cb9c8;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row16_col1{
#             background-color:  #842550;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row16_col2{
#             background-color:  #ac4d51;
#             color:  #f1f1f1;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row16_col3{
#             background-color:  #b15552;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row16_col4{
#             background-color:  #88acc4;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row17_col4{
#             background-color:  #a7c0cb;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row18_col1{
#             background-color:  #6171b9;
#             color:  #000000;
#         }#T_17e76f16_e701_11eb_b657_0242ac1c0002row18_col2{
#             background-color:  #6173ba;

# %%
fig = px.bar(month_wise, x='Date', y='Confirmed',
             hover_data=['Cured', 'Deaths'], color='Date',
             labels={'Date':'Date(monthwise)'}, height=400,
             title="Monthwise Increase in Confirmed cases")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7af8fa80-3dcc-41be-b175-865ab03e4df3" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7af8fa80-3dcc-41be-b175-865ab03e4df3")) {
#                     Plotly.newPlot(
#                         '7af8fa80-3dcc-41be-b175-865ab03e4df3',
#                         [{"alignmentgroup": "True", "customdata": [[0, 0]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Confirmed=%{y}<br>Cured=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-01-31 00:00:00", "marker": {"color": "#636efa"}, "name": "Date(monthwise)=2020-01-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-01-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-01-31T00:00:00"], "xaxis": "x", "y": [2], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[0, 0]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Confirmed=%{y}<br>Cured=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-02-29 00:00:00", "marker": {"color": "#EF553B"}, "name": "Date(monthwise)=2020-02-29 00:00:00", "offsetgroup": "Date(monthwise)=2020-02-29 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-02-29T00:00:00"], "xaxis": "x", "y": [86], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[808, 202]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Confirmed=%{y}<br>Cured=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-03-31 00:00:00", "marker": {"color": "#00cc96"}, "name": "Date(monthwise)=2020-03-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-03-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-03-31T00:00:00"], "xaxis": "x", "y": [9687], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[75443, 13270]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Confirmed=%{y}<br>Cured=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-04-30 00:00:00", "marker": {"color": "#ab63fa"}, "name": "Date(monthwise)=2020-04-30 00:00:00", "offsetgroup": "Date(monthwise)=2020-04-30 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-04-30T00:00:00"], "xaxis": "x", "y": [422442], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[1133341, 89834]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Confirmed=%{y}<br>Cured=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-05-31 00:00:00", "marker": {"color": "#FFA15A"}, "name": "Date(monthwise)=2020-05-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-05-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-05-31T00:00:00"], "xaxis": "x", "y": [2938234], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[5668946, 319690]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Confirmed=%{y}<br>Cured=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-06-30 00:00:00", "marker": {"color": "#19d3f3"}, "name": "Date(monthwise)=2020-06-30 00:00:00", "offsetgroup": "Date(monthwise)=2020-06-30 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-06-30T00:00:00"], "xaxis": "x", "y": [10558374], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[19980130, 793511]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Confirmed=%{y}<br>Cured=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-07-31 00:00:00", "marker": {"color": "#FF6692"}, "name": "Date(monthwise)=2020-07-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-07-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-07-31T00:00:00"], "xaxis": "x", "y": [31726501], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[58580895, 1553468]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Confirmed=%{y}<br>Cured=%{customdata[0]}<br>D ...

# %%
fig = px.bar(month_wise, x='Date', y='Cured',
             hover_data=['Confirmed','Deaths'], color='Date',
             labels={'Date':'Date(monthwise)'},
             title="Monthwise Increase in Cured cases")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b0e63b51-bec9-4ee2-b46a-30767f13a19a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b0e63b51-bec9-4ee2-b46a-30767f13a19a")) {
#                     Plotly.newPlot(
#                         'b0e63b51-bec9-4ee2-b46a-30767f13a19a',
#                         [{"alignmentgroup": "True", "customdata": [[2, 0]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Cured=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-01-31 00:00:00", "marker": {"color": "#636efa"}, "name": "Date(monthwise)=2020-01-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-01-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-01-31T00:00:00"], "xaxis": "x", "y": [0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[86, 0]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Cured=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-02-29 00:00:00", "marker": {"color": "#EF553B"}, "name": "Date(monthwise)=2020-02-29 00:00:00", "offsetgroup": "Date(monthwise)=2020-02-29 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-02-29T00:00:00"], "xaxis": "x", "y": [0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[9687, 202]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Cured=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-03-31 00:00:00", "marker": {"color": "#00cc96"}, "name": "Date(monthwise)=2020-03-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-03-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-03-31T00:00:00"], "xaxis": "x", "y": [808], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[422442, 13270]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Cured=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-04-30 00:00:00", "marker": {"color": "#ab63fa"}, "name": "Date(monthwise)=2020-04-30 00:00:00", "offsetgroup": "Date(monthwise)=2020-04-30 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-04-30T00:00:00"], "xaxis": "x", "y": [75443], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[2938234, 89834]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Cured=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-05-31 00:00:00", "marker": {"color": "#FFA15A"}, "name": "Date(monthwise)=2020-05-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-05-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-05-31T00:00:00"], "xaxis": "x", "y": [1133341], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[10558374, 319690]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Cured=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-06-30 00:00:00", "marker": {"color": "#19d3f3"}, "name": "Date(monthwise)=2020-06-30 00:00:00", "offsetgroup": "Date(monthwise)=2020-06-30 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-06-30T00:00:00"], "xaxis": "x", "y": [5668946], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[31726501, 793511]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Cured=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-07-31 00:00:00", "marker": {"color": "#FF6692"}, "name": "Date(monthwise)=2020-07-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-07-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-07-31T00:00:00"], "xaxis": "x", "y": [19980130], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[80749620, 1553468]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Cured=%{y}<br>Confirmed=%{customdata[0]}<br>D ...

# %%
fig = px.bar(month_wise, x='Date', y='Deaths',
             hover_data=['Confirmed','Cured'], color='Date',
             labels={'Date':'Date(monthwise)'},
             title="Monthwise Increase in Deaths cases")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d3e71b8c-efeb-4121-98e6-39db07203c6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d3e71b8c-efeb-4121-98e6-39db07203c6f")) {
#                     Plotly.newPlot(
#                         'd3e71b8c-efeb-4121-98e6-39db07203c6f',
#                         [{"alignmentgroup": "True", "customdata": [[2, 0]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Deaths=%{y}<br>Confirmed=%{customdata[0]}<br>Cured=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-01-31 00:00:00", "marker": {"color": "#636efa"}, "name": "Date(monthwise)=2020-01-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-01-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-01-31T00:00:00"], "xaxis": "x", "y": [0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[86, 0]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Deaths=%{y}<br>Confirmed=%{customdata[0]}<br>Cured=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-02-29 00:00:00", "marker": {"color": "#EF553B"}, "name": "Date(monthwise)=2020-02-29 00:00:00", "offsetgroup": "Date(monthwise)=2020-02-29 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-02-29T00:00:00"], "xaxis": "x", "y": [0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[9687, 808]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Deaths=%{y}<br>Confirmed=%{customdata[0]}<br>Cured=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-03-31 00:00:00", "marker": {"color": "#00cc96"}, "name": "Date(monthwise)=2020-03-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-03-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-03-31T00:00:00"], "xaxis": "x", "y": [202], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[422442, 75443]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Deaths=%{y}<br>Confirmed=%{customdata[0]}<br>Cured=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-04-30 00:00:00", "marker": {"color": "#ab63fa"}, "name": "Date(monthwise)=2020-04-30 00:00:00", "offsetgroup": "Date(monthwise)=2020-04-30 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-04-30T00:00:00"], "xaxis": "x", "y": [13270], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[2938234, 1133341]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Deaths=%{y}<br>Confirmed=%{customdata[0]}<br>Cured=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-05-31 00:00:00", "marker": {"color": "#FFA15A"}, "name": "Date(monthwise)=2020-05-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-05-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-05-31T00:00:00"], "xaxis": "x", "y": [89834], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[10558374, 5668946]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Deaths=%{y}<br>Confirmed=%{customdata[0]}<br>Cured=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-06-30 00:00:00", "marker": {"color": "#19d3f3"}, "name": "Date(monthwise)=2020-06-30 00:00:00", "offsetgroup": "Date(monthwise)=2020-06-30 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-06-30T00:00:00"], "xaxis": "x", "y": [319690], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[31726501, 19980130]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Deaths=%{y}<br>Confirmed=%{customdata[0]}<br>Cured=%{customdata[1]}", "legendgroup": "Date(monthwise)=2020-07-31 00:00:00", "marker": {"color": "#FF6692"}, "name": "Date(monthwise)=2020-07-31 00:00:00", "offsetgroup": "Date(monthwise)=2020-07-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-07-31T00:00:00"], "xaxis": "x", "y": [793511], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[80749620, 58580895]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date(monthwise)=%{x}<br>Deaths=%{y}<br>Confirmed=%{customdata[0]}<br ...

# %%
fig = px.bar(month_wise , 
             x='Date', 
             y='Death_percentage' ,
             hover_data=['Confirmed','Deaths'],color='Date',
             labels={'Death_percentage':'Death percentage'},
             title="Top 10 states with highest of Death percentage rate ")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8d9d8f8b-86ac-49a0-b0a7-a734f7ea4268" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8d9d8f8b-86ac-49a0-b0a7-a734f7ea4268")) {
#                     Plotly.newPlot(
#                         '8d9d8f8b-86ac-49a0-b0a7-a734f7ea4268',
#                         [{"alignmentgroup": "True", "customdata": [[2, 0]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Death percentage=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date=2020-01-31 00:00:00", "marker": {"color": "#636efa"}, "name": "Date=2020-01-31 00:00:00", "offsetgroup": "Date=2020-01-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-01-31T00:00:00"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[86, 0]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Death percentage=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date=2020-02-29 00:00:00", "marker": {"color": "#EF553B"}, "name": "Date=2020-02-29 00:00:00", "offsetgroup": "Date=2020-02-29 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-02-29T00:00:00"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[9687, 202]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Death percentage=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date=2020-03-31 00:00:00", "marker": {"color": "#00cc96"}, "name": "Date=2020-03-31 00:00:00", "offsetgroup": "Date=2020-03-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-03-31T00:00:00"], "xaxis": "x", "y": [2.0852689171053993], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[422442, 13270]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Death percentage=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date=2020-04-30 00:00:00", "marker": {"color": "#ab63fa"}, "name": "Date=2020-04-30 00:00:00", "offsetgroup": "Date=2020-04-30 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-04-30T00:00:00"], "xaxis": "x", "y": [3.141259628540723], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[2938234, 89834]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Death percentage=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date=2020-05-31 00:00:00", "marker": {"color": "#FFA15A"}, "name": "Date=2020-05-31 00:00:00", "offsetgroup": "Date=2020-05-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-05-31T00:00:00"], "xaxis": "x", "y": [3.0574147600225166], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[10558374, 319690]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Death percentage=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date=2020-06-30 00:00:00", "marker": {"color": "#19d3f3"}, "name": "Date=2020-06-30 00:00:00", "offsetgroup": "Date=2020-06-30 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-06-30T00:00:00"], "xaxis": "x", "y": [3.027833641808862], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[31726501, 793511]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Death percentage=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date=2020-07-31 00:00:00", "marker": {"color": "#FF6692"}, "name": "Date=2020-07-31 00:00:00", "offsetgroup": "Date=2020-07-31 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-07-31T00:00:00"], "xaxis": "x", "y": [2.5010983719887676], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[80749620, 1553468]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Death percentage=%{y}<br>Confirmed=%{customdata[0]}<br>Deaths=%{customdata[1]}", "legendgroup": "Date=2020-08-31 00:00:00", "marker": {"color": "#B6E880"}, "name": "Date=2020-08-31 00:00:00", "offsetgroup": "Date=2020-08-31 0 ...
